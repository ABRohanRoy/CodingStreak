# %%
print("Hello")
# Out:
# Hello

# %%
x=5
print(x)
# Out:
# 5

# %%
x=1
y=4
print(x,y)
# Out:
# 1 4

# %%
print(x,y,"both these values are goingto be printed")
# Out:
# 1 4 both these values are goingto be printed

# %%
print(x)
print(y)
# Out:
# 1
# 4

# %%
print(5)
print()
print(7)
# Out:
# 5
#
# 7
