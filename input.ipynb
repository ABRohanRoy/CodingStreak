# %%
print("hello")
# Out:
# hello

# %%
"hello"
'hello'
'hey'
"hey"
# all are string
# Out:
# 'hey'

# %%
# user input
name=input()
print(name)
# Out:
# Rohan

# %%
info=input()
print(info)
# Out:
# Rohan is learning python

# %%
age=input()
print(age)
# Out:
# 155

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
age=int(input())
print(type(age))
# Out:
# <class 'int'>

# %%
salary=float(input())
print(salary)
# Out:
# 150000.0

# %%
print(type(salary))
# Out:
# <class 'float'>

# %%
isAdmin=bool(input())
print(type(isAdmin))
# Out:
# <class 'bool'>

# %%
# Multiple inputs
num=input().split()
print(num,type(num))
# Out:
# ['1', '2', '3'] <class 'list'>

# %%
a,b,c=map(int,input().split())
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3

# %%
a,b,c=map(int,input().split("."))
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3

# %%
list = list(map(int,input().split()))
print(list)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 4, 6, 4, 5, 6, 6, 2, 1, 5, 5]

# %%
print(len(list))
# Out:
# 19
